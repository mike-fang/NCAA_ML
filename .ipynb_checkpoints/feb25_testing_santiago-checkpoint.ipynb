# %% [markdown]
# Data Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split

# %matplotlib inline

compact_result_season = pd.read_csv('./data/DataFiles/RegularSeasonCompactResults.csv')

# %%
#import the file with team IDs
team_ids = pd.read_csv('./data/DataFiles/Teams.csv')
team_ids.head()
# Out:
#    TeamID     TeamName  FirstD1Season  LastD1Season
# 0    1101  Abilene Chr           2014          2018
# 1    1102    Air Force           1985          2018
# 2    1103        Akron           1985          2018
# 3    1104      Alabama           1985          2018
# 4    1105  Alabama A&M           2000          2018

# %% [markdown]
# Groupby command to pull up wins

# %%
train, test = train_test_split(compact_result_season, test_size=.2)

# %%
wins_mat = train.groupby('WTeamID').size().to_frame()
loss_mat = train.groupby('LTeamID').size().to_frame()

# %%
simplee_prop = (wins_mat)/(wins_mat+loss_mat)

simplee_prop.columns=['Win_prop']

simplee_prop['TeamID'] = simplee_prop.index

# %%
merged_with_ids = pd.merge(simplee_prop, team_ids)

sorted_wins =merged_with_ids.sort_values('Win_prop', ascending=False).reset_index()


sorted_wins.reset_index().plot(y= 'Win_prop', use_index = True)

simplee_prop.sort_index()
# Out:
#          Win_prop  TeamID
# WTeamID
# 1101     0.289474    1101
# 1102     0.353198    1102
# 1103     0.567885    1103
# 1104     0.612702    1104
# 1105     0.373016    1105
# 1106     0.461972    1106
# 1107     0.481651    1107
# 1108     0.347633    1108
# 1109     0.233577    1109
# 1110     0.465241    1110
# 1111     0.452347    1111
# 1112     0.759569    1112
# 1113     0.509728    1113
# 1114     0.535714    1114
# 1115     0.288889    1115
# 1116     0.636919    1116
# 1117     0.506579    1117
# 1118     0.240000    1118
# 1119     0.328632    1119
# 1120     0.509628    1120
# 1121     0.267606    1121
# 1122     0.486595    1122
# 1123     0.524634    1123
# 1124     0.500000    1124
# 1125     0.643182    1125
# 1126     0.345550    1126
# 1127     0.346667    1127
# 1128     0.622222    1128
# 1129     0.565737    1129
# 1130     0.508929    1130
# ...           ...     ...
# 1435     0.607323    1435
# 1436     0.538163    1436
# 1437     0.652010    1437
# 1438     0.599490    1438
# 1439     0.509728    1439
# 1440     0.315328    1440
# 1441     0.366337    1441
# 1442     0.343750    1442
# 1443     0.605634    1443
# 1444     0.500000    1444
# 1445     0.200000    1445
# 1446     0.342105    1446
# 1447     0.476000    1447
# 1448     0.555985    1448
# 1449     0.528947    1449
# 1450     0.454305    1450
# 1451     0.558659    1451
# 1452     0.614213    1452
# 1453     0.555707    1453
# 1454     0.477273    1454
# 1455     0.575495    1455
# 1456     0.380822    1456
# 1457     0.502235    1457
# 1458     0.633803    1458
# 1459     0.410148    1459
# 1460     0.530702    1460
# 1461     0.542553    1461
# 1462     0.701777    1462
# 1463     0.478632    1463
# 1464     0.337449    1464
#
# [364 rows x 2 columns]

# %% [markdown]
# Function to calculate probability based on simple model

# %%
def calc_win(row):
    # prop that team_i wins over team_j
    i = row['WTeamID']
    j = row['LTeamID']
    pw_i = float(simplee_prop[simplee_prop['TeamID'] == i]['Win_prop'])
    pw_j = float(simplee_prop[simplee_prop['TeamID'] == j]['Win_prop'])
    return 1. / (1 + (pw_j / pw_i) * (1 - pw_i)/(1 - pw_j))

# %%
test['win_prob'] = test.apply(calc_win, axis=1)
# Out:
# /Users/Santiago/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test['win_prob'].plot.hist(bins=50)

# %%
named_test = pd.merge(test, team_ids[['TeamID', 'TeamName']], left_on='WTeamID', right_on='TeamID')

# %% [markdown]
# Manipulate the data to include the right column names

# %%
named_test.columns = [u'Season', u'DayNum', u'WTeamID', u'WScore', u'LTeamID', u'LScore',
       u'WLoc', u'NumOT', u'win_prob', u'TeamID', u'WTeamName']

named_test = named_test.drop('TeamID', axis=1)

named_test = pd.merge(named_test, team_ids[['TeamID', 'TeamName']], left_on='LTeamID', right_on='TeamID')

named_test.columns = [   u'Season',    u'DayNum',   u'WTeamID',    u'WScore',   u'LTeamID',
          u'LScore',      u'WLoc',     u'NumOT',  u'win_prob', u'WTeamName',
          u'TeamID',  u'LTeamName']

# %%
named_test.drop('TeamID', axis=1, inplace=True)

named_test.sort_values('win_prob')
# Out:
#        Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  win_prob  \
# 20567    1985      62     1327      53     1264      52    H      0  0.104369
# 19250    1988      61     1226      63     1211      60    H      0  0.155601
# 25487    2011      23     1342      69     1343      67    N      0  0.160039
# 19273    1991      82     1339      67     1211      63    H      0  0.169356
# 19272    1990     107     1339      68     1211      64    A      0  0.169356
# 30123    2017      28     1188      76     1213      64    A      0  0.173634
# 9506     2001     105     1154      62     1158      58    H      0  0.178142
# 12413    1994     122     1363      80     1424      74    A      0  0.178730
# 18743    1985     107     1152      65     1103      63    A      0  0.181064
# 17816    2007      66     1170      80     1285      72    H      0  0.184303
# 17818    2003     124     1170      88     1285      75    N      0  0.184303
# 17817    2017      82     1170      92     1285      83    H      0  0.184303
# 12934    2005      89     1450      70     1112      63    A      0  0.188009
# 12933    2010      96     1450      78     1112      60    H      0  0.188009
# 12904    1985      87     1333      59     1112      55    H      0  0.189488
# 30085    2014      26     1152      88     1356      84    H      0  0.191401
# 19474    1985     108     1446      68     1229      66    H      0  0.191619
# 28460    2007      96     1401      69     1242      66    A      0  0.191640
# 28448    2005     105     1403      80     1242      79    H      2  0.191680
# 832      2017      61     1439      89     1181      75    H      0  0.192025
# 19284    1990      70     1186      70     1211      55    A      0  0.193827
# 7457     2000     103     1410      79     1125      69    H      0  0.194987
# 16977    1985      80     1152      82     1453      60    H      0  0.197290
# 16978    1986     101     1152      81     1453      62    H      0  0.197290
# 28472    1991      25     1113      70     1242      68    H      0  0.199228
# 12406    2013     100     1102      71     1424      56    H      0  0.199928
# 12407    2015     103     1102      76     1424      75    H      0  0.199928
# 28458    2013     124     1124      81     1242      58    H      0  0.200150
# 28457    2009     129     1124      71     1242      64    N      0  0.200150
# 19299    1989     124     1258     101     1211      98    N      0  0.201228
# ...       ...     ...      ...     ...      ...     ...  ...    ...       ...
# 9786     2002      59     1332      96     1289      50    H      0  0.878069
# 13221    1992      56     1181      97     1456      91    H      0  0.878291
# 13220    2000      62     1181      96     1456      55    H      0  0.878291
# 13219    2017      23     1181      88     1456      67    H      0  0.878291
# 13217    1990      84     1181     109     1456      76    A      0  0.878291
# 13218    1989      72     1181     100     1456      38    H      0  0.878291
# 23173    2011      59     1328      76     1146      73    H      0  0.878404
# 23174    2016      31     1328     111     1146      68    H      0  0.878404
# 16819    2001      68     1424     106     1152      71    H      0  0.879405
# 28219    2012      52     1112     100     1136      60    H      0  0.880005
# 9785     2002      19     1155      70     1289      57    N      0  0.881025
# 23760    2004      56     1242      78     1127      46    H      0  0.884462
# 28621    2005      59     1153      95     1255      69    N      0  0.886724
# 16845    1999      26     1462      90     1152      50    H      0  0.888147
# 8276     1992      19     1242     122     1420      58    H      0  0.892279
# 6614     2012      30     1242      77     1194      54    H      0  0.898411
# 14766    2013      21     1242      70     1363      57    H      0  0.899003
# 26994    2000      19     1181     100     1119      42    H      0  0.900963
# 26995    1998      20     1181      78     1119      45    A      0  0.900963
# 26993    2015      27     1181      93     1119      73    H      0  0.900963
# 16808    1998      35     1211      97     1152      51    A      0  0.901410
# 30136    1985     105     1331      81     1327      61    A      0  0.904590
# 24618    1989      26     1181      93     1154      52    H      0  0.905902
# 24619    1991      79     1181      83     1154      50    A      0  0.905902
# 24620    1990      65     1181     108     1154      69    H      0  0.905902
# 10147    1990      60     1242     103     1410      83    N      0  0.906177
# 8655     2009       7     1181      80     1342      49    H      0  0.930881
# 23164    2010      17     1242      94     1146      44    H      0  0.933057
# 28917    2007      50     1242      94     1445      43    H      0  0.938937
# 28585    2011      11     1242     113     1255      75    H      0  0.939662
#
#            WTeamName       LTeamName
# 20567      Okla City       Manhattan
# 19250       Idaho St         Gonzaga
# 25487   Presbyterian       Princeton
# 19273       Portland         Gonzaga
# 19272       Portland         Gonzaga
# 30123   Edwardsville    Grand Canyon
# 9506         Citadel  Col Charleston
# 12413    San Jose St            UNLV
# 18743     Chicago St           Akron
# 17816  CS Sacramento         Montana
# 17818  CS Sacramento         Montana
# 17817  CS Sacramento         Montana
# 12934  Washington St         Arizona
# 12933  Washington St         Arizona
# 12904      Oregon St         Arizona
# 30085     Chicago St      S Illinois
# 19474    W Texas A&M     Illinois St
# 28460      Texas A&M          Kansas
# 28448     Texas Tech          Kansas
# 832    Virginia Tech            Duke
# 19284   E Washington         Gonzaga
# 7457           UTRGV         Belmont
# 16977     Chicago St    WI Green Bay
# 16978     Chicago St    WI Green Bay
# 28472     Arizona St          Kansas
# 12406      Air Force            UNLV
# 12407      Air Force            UNLV
# 28458         Baylor          Kansas
# 28457         Baylor          Kansas
# 19299  Loy Marymount         Gonzaga
# ...              ...             ...
# 9786          Oregon    Morris Brown
# 13221           Duke  William & Mary
# 13220           Duke  William & Mary
# 13219           Duke  William & Mary
# 13217           Duke  William & Mary
# 13218           Duke  William & Mary
# 23173       Oklahoma   Cent Arkansas
# 23174       Oklahoma   Cent Arkansas
# 16819           UNLV      Chicago St
# 28219        Arizona          Bryant
# 9785         Clemson    Morris Brown
# 23760         Kansas      Binghamton
# 28621     Cincinnati        Longwood
# 16845         Xavier      Chicago St
# 8276          Kansas            UMBC
# 6614          Kansas     FL Atlantic
# 14766         Kansas     San Jose St
# 26994           Duke            Army
# 26995           Duke            Army
# 26993           Duke            Army
# 16808        Gonzaga      Chicago St
# 30136   Oral Roberts       Okla City
# 24618           Duke         Citadel
# 24619           Duke         Citadel
# 24620           Duke         Citadel
# 10147         Kansas           UTRGV
# 8655            Duke    Presbyterian
# 23164         Kansas   Cent Arkansas
# 28917         Kansas      W Salem St
# 28585         Kansas        Longwood
#
# [30137 rows x 11 columns]

# %%
conference_df = pd.read_csv('./data/DataFiles/TeamConferences.csv')

conference_df['ConfAbbrev'].unique()
# Out:
# array(['a_sun', 'a_ten', 'acc', 'big_east', 'big_eight', 'big_sky',
#        'big_ten', 'ecacm', 'ecacn', 'ecacs', 'ecc', 'gsc', 'ind', 'ivy',
#        'maac', 'mac', 'meac', 'metro', 'mid_cont', 'mvc', 'mw_city', 'ovc',
#        'pac_ten', 'pcaa', 'sec', 'southern', 'southland', 'sun_belt',
#        'swac', 'swc', 'wac', 'wcc', 'big_south', 'caa', 'mw_coll', 'asc',
#        'big_west', 'nac', 'nec', 'patriot', 'gmwc', 'awc', 'cusa', 'aec',
#        'big_twelve', 'mwc', 'horizon', 'summit', 'gwc', 'pac_twelve', 'aac'], dtype=object)

# %%
compact_result_season = pd.merge(compact_result_season, conference_df, left_on=['Season', 'WTeamID'], right_on=['Season', 'TeamID'])
compact_result_season.columns
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  TeamID  \
# 0    1985      20     1228      81     1328      64    N      0    1228
# 1    1985      25     1228      64     1226      44    N      0    1228
# 2    1985      27     1228      75     1332      72    N      3    1228
# 3    1985      30     1228      81     1152      63    H      0    1228
# 4    1985      33     1228      73     1328      70    H      0    1228
#
#   ConfAbbrev
# 0    big_ten
# 1    big_ten
# 2    big_ten
# 3    big_ten
# 4    big_ten

# %%
compact_result_season.columns = [u'Season', u'DayNum', u'WTeamID', u'WScore', u'LTeamID', u'LScore',
       u'WLoc', u'NumOT', u'TeamID', u'WConf']

# %%
compact_result_season.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  TeamID  \
# 0    1985      20     1228      81     1328      64    N      0    1228
# 1    1985      25     1228      64     1226      44    N      0    1228
# 2    1985      27     1228      75     1332      72    N      3    1228
# 3    1985      30     1228      81     1152      63    H      0    1228
# 4    1985      33     1228      73     1328      70    H      0    1228
#
#      WConf
# 0  big_ten
# 1  big_ten
# 2  big_ten
# 3  big_ten
# 4  big_ten

# %%
compact_result_season.drop('TeamID', axis=1, inplace=True)

# %%
compact_result_season = pd.merge(compact_result_season, conference_df, left_on=['Season', 'LTeamID'], right_on=['Season', 'TeamID'])

# %%
compact_result_season.drop('TeamID', axis=1, inplace=True)

# %%
compact_result_season.columns = [    u'Season',     u'DayNum',    u'WTeamID',     u'WScore',
          u'LTeamID',     u'LScore',       u'WLoc',      u'NumOT',
            u'WConf', u'LConf']

# %%
PPG_season_W_mean = compact_result_season.groupby(['WTeamID', 'Season'])['WScore'].mean().to_frame()

# %%
PPG_season_W_mean.reset_index(inplace=True)

# %%
PPG_season_W_mean.columns = [u'WTeamID', u'Season', u'season_mean_WScore']

# %%
compact_result_season = pd.merge(compact_result_season, PPG_season_W_mean)

# %%
PPG_season_L_mean = compact_result_season.groupby(['LTeamID', 'Season'])['LScore'].mean().to_frame()

# %%
PPG_season_L_mean.reset_index(inplace=True)
PPG_season_L_mean.columns = [u'LTeamID', u'Season', u'season_mean_LScore']

# %%
compact_result_season = pd.merge(compact_result_season, PPG_season_L_mean)

# %%
compact_result_season.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT      WConf  \
# 0    1985      20     1228      81     1328      64    N      0    big_ten
# 1    1985      33     1228      73     1328      70    H      0    big_ten
# 2    1985     118     1242      82     1328      76    H      0  big_eight
# 3    1985      54     1374      85     1328      76    N      0        swc
# 4    1985      72     1409     104     1328      89    H      0        mvc
#
#        LConf  season_mean_WScore  season_mean_LScore
# 0  big_eight           73.217391                75.0
# 1  big_eight           73.217391                75.0
# 2  big_eight           78.652174                75.0
# 3  big_eight           78.772727                75.0
# 4  big_eight           82.136364                75.0
